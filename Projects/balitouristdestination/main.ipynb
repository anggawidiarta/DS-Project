# %%
import pandas as pd

# %%
df = pd.read_csv('./Bali Popular Destination for Tourist 2022 - Sheet1.csv')
df.shape
# Out:
# (34, 8)

# %%
df.head()
# Out:
#                 Place                                           Location  \
# 0           Tanah Lot  Beraban, Kec. Kediri, Kabupaten Tabanan, Bali ...
# 1         Mount Batur                    Bangli Regency, Bali, Indonesia
# 2      Uluwatu Temple                       Uluwatu (South Kuta, Badung)
# 3  Ubud Monkey Forest  Jl. Monkey Forest, Ubud, Kecamatan Ubud, Kabup...
# 4           Goa Gajah                              Gianyar Regency, Bali
#
#                Coordinate  Google Maps Rating  Google Reviews (Count)  \
# 0  8.6212° S, 115.0868° E                 4.6                   75899
# 1   8°14′20″S 115°22′39″E                 4.5                    2580
# 2  8.8291° S, 115.0849° E                 4.6                   28800
# 3  8.5194° S, 115.2606° E                 4.5                   36099
# 4  8.5069° S, 115.2625° E                 4.2                    6683
#
#                                               Source  \
# ...

# %%
df.sort_values('Google Maps Rating',ascending=False).reset_index(drop=True)
# Out:
#                                  Place  \
# 0                  Penglipuran Village
# 1                       Waterboom Bali
# 2                     Goa Lawah Temple
# 3      Jatiluwih Rice Terraces in Bali
# 4                Pura Ulun Danu Bratan
# 5                Secret Garden Village
# 6                          Taman Ujung
# 7                         Tirta Gangga
# 8                       Bali Bird Park
# 9                   Tirta Empul Temple
# 10                           Tanah Lot
# 11                      Nusa Dua Beach
# 12                      Uluwatu Temple
# 13               Bajra Sandhi Monument
# 14                          Kuta Beach
# 15       Besakih Temple (Pura Besakih)
# 16             West Bali National Park
# 17  Garuda Wisnu Kencana Cultural Park
# 18                         Mount Batur
# 19                      Seminyak Beach
# 20                         Bali Pulina
# 21                  Ubud Monkey Forest
# 22                          Bali Swing
# ...
